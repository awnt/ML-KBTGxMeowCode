# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Building the dataset
#
# - generate regression dataset
# - generate classification dataset

# %% [markdown]
# ## 1. Regression Dataset

# %%
from sklearn.datasets import make_regression

# %%
# generate regression dataset
X, y = make_regression(n_samples=1000, n_features=1, noise=100, shuffle=True, random_state=27)

# %%
df = pd.DataFrame(X, index=range(len(X)), columns=["X"])
df["Y"] = y

# %%
df.head()
# Out:
#           X           Y
# 0 -0.168005 -107.480692
# 1  1.393876  201.944833
# 2 -0.250787   84.740862
# 3  0.013533   60.527183
# 4 -0.776702  -26.201326

# %%
df.to_csv("dataset/reg_uni.csv")

# %%
# plot regression dataset
plt.figure(figsize=(10,10))
plt.scatter(X,y)
plt.show()

# %%
# generate regression dataset
X, y = make_regression(n_samples=50, n_features=3, noise=0.1, shuffle=True, random_state=27)

# %%
X.shape
# Out:
# (50, 3)

# %%
df = pd.DataFrame(dict(X1=X[:,0], X2=X[:, 1], X3=X[:,2], Y=y))
df.head()
# Out:
#          X1        X2        X3           Y
# 0 -2.166068 -1.247767  0.285685 -184.980982
# 1  0.154733  0.562757  1.033058  136.596165
# 2 -0.144426  0.591353 -0.037168   10.231184
# 3  1.501099  0.195870  1.901946  307.014161
# 4  1.056678  0.056822 -0.020623   78.958628

# %%
# plot regression dataset
plt.figure(figsize=(10,10))
plt.scatter(df["X1"], df["Y"], color="r")
plt.scatter(df["X2"], df["Y"], color="g")
plt.scatter(df["X3"], df["Y"], color="b")
plt.show()

# %%
df.to_csv("dataset/reg_mult.csv")

# %% [markdown]
# ## 2. Classification dataset

# %% [markdown]
# ## 2.1 make_blobs

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=100, centers=3, n_features=2)

# %%
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
df.head()
# Out:
#           x         y  label
# 0 -5.821299 -0.412665      2
# 1 -3.387784  7.991480      0
# 2 -2.455643  0.909719      1
# 3 -4.775160 -0.453571      2
# 4 -1.290647  8.720120      0

# %%
# group dataset by label
grouped = df.groupby('label')

# plot classification dataset
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = plt.subplots()
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key], figsize=(10,8))
plt.show()

# %%
df.to_csv("dataset/class_blobs.csv")

# %% [markdown]
# ## 2.2 make_moons

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=500, noise=0.1)

# %%
X
# Out:
# array([[ 0.03058033,  0.69346941],
#        [ 0.11790351, -0.0197072 ],
#        [ 1.96556665,  0.23257625],
#        [-0.03593005,  0.24081905],
#        [ 1.42612209, -0.42233022],
#        [-0.34936766,  1.0008321 ],
#        [-0.53557295,  0.79919579],
#        [ 1.0745914 ,  0.34648639],
#        [-0.01352919,  0.32605409],
#        [ 0.02394136,  0.01109888],
#        [-0.79140252,  0.61529345],
#        [-0.920457  ,  0.0158836 ],
#        [-1.03356253,  0.19646399],
#        [-0.51205183,  1.03686328],
#        [ 1.11865014,  0.18431939],
#        [-1.01496462,  0.50044887],
#        [ 0.79680898, -0.45336741],
#        [ 0.37465285,  1.0122582 ],
#        [ 0.70074038, -0.39315543],
#        [-0.05128664,  0.8328072 ],
#        [ 0.54959956, -0.50648878],
#        [ 0.08755652,  0.96942477],
#        [-0.84451874,  0.28065371],
#        [ 1.82621703, -0.29043143],
#        [ 1.9954386 ,  0.20355474],
#        [ 0.9423937 , -0.37575872],
#        [-0.09061641,  0.41391218],
#        [-0.79029059,  0.34682616],
#        [ 0.09591256, -0.13202613],
#        [ 0.48587764,  0.73549511],
#        [ 0.95473529,  0.14391741],
#        [ 0.4486804 ,  0.86817926],
#        [-0.72865166,  0.5996432 ],
#        [ 0.48266828, -0.5885526 ],
#        [ 0.90588659,  0.15787724],
#        [-0.69703443,  0.83273581],
#        [-0.96405757,  0.47039493],
#        [ 1.05723769,  0.44826817],
#        [ 1.32688534, -0.40271578],
#        [ 2.09666141,  0.23534913],
#        [ 1.29027079, -0.48620508],
#        [ 1.35045294, -0.38693345],
#        [ 0.27745741, -0.2211681 ],
#        [ 1.08258162, -0.32508523],
#        [ 0.30723916,  0.94596836],
#        [ 2.00165542,  0.07188308],
#        [ 0.86894971,  0.11943208],
#        [ 0.10696918,  0.63483733],
#        [-0.30365437,  0.9453115 ],
#        [-1.00523263,  0.2506968 ],
#        [ 0.04684641,  0.33979099],
#        [ 0.50022142,  0.53209183],
#        [ 1.75385849, -0.0046454 ],
#        [ 2.15781249,  0.41770268],
#        [ 0.76646332,  0.51892704],
#        [ 0.9055676 , -0.43548757],
#        [ 1.09364913,  0.21832117],
#        [-1.0361617 ,  0.41376679],
#        [ 0.7618553 ,  0.67028723],
#        [-0.04366267,  1.01852728],
#        [ 1.56924769, -0.3446444 ],
#        [-0.94867003,  0.55302749],
#        [ 0.2469115 ,  0.98903542],
#        [ 0.53469882,  0.76867044],
#        [-0.98430123,  0.39117804],
#        [ 0.20246481,  0.93998619],
#        [-0.23699335,  1.13199316],
#        [ 0.58313002,  0.87112328],
#        [-0.78810731,  0.3394324 ],
#        [-0.90414562,  0.14384318],
#        [ 0.90013778, -0.67816625],
#        [-0.88993138,  0.5840779 ],
#        [ 0.88952196,  0.80839202],
#        [-0.62276756,  0.92123687],
#        [ 2.15057369,  0.47388016],
#        [-0.13234958,  0.86800341],
#        [ 0.51632935, -0.33101575],
#        [ 1.02178723, -0.58902287],
#        [ 1.82214142, -0.15039616],
#        [ 0.79550069,  0.38334259],
#        [ 0.35329644, -0.36771814],
#        [ 0.40748893, -0.2058394 ],
#        [-1.05461367,  0.17651048],
#        [-0.05375811,  0.47363885],
#        [-0.90177985,  0.77224356],
#        [-0.17750748,  0.81972977],
#        [ 0.16636361,  1.07794995],
#        [-0.36470937,  0.89178994],
#        [-0.83721124,  0.30250181],
#        [ 0.45692467,  1.04033616],
#        [-0.46131796,  0.96356412],
#        [ 0.84000664, -0.31590734],
#        [ 0.93714497, -0.55201178],
#        [ 0.99267145, -0.43670746],
#        [ 0.51758577, -0.29496572],
#        [ 1.22333227, -0.36096668],
#        [ 0.111144  ,  0.35579088],
#        [ 1.7777765 ,  0.06150351],
#        [ 0.02964199,  1.09092095],
#        [-0.18683809,  0.88151613],
#        [-0.49386191,  0.8403899 ],
#        [ 0.49719982,  0.79769934],
#        [ 0.58534413, -0.53880254],
#        [-0.45681182,  0.78442182],
#        [-0.81825406,  0.47197559],
#        [ 1.66261941, -0.20406641],
#        [ 1.22543494, -0.48654278],
#        [-0.04051168,  0.39579039],
#        [ 1.56034086, -0.39182797],
#        [ 0.55923751,  0.78984183],
#        [ 1.57047079, -0.26648804],
#        [ 0.04874715,  0.93117428],
#        [ 0.07416207,  0.17465998],
#        [ 1.05192899, -0.54024657],
#        [ 0.89444225,  0.39121862],
#        [ 0.55901374,  0.90394874],
#        [ 0.0542486 ,  0.39366862],
#        [ 0.05601644,  0.27762473],
#        [ 1.47094627, -0.08456819],
#        [ 1.53120378, -0.20227978],
#        [ 0.76496314,  0.62101802],
#        [ 1.04728062,  0.42659622],
#        [ 0.54268656, -0.38281073],
#        [ 0.79293344, -0.51687865],
#        [ 0.92077952, -0.28592777],
#        [ 0.41392907, -0.41990449],
#        [ 0.44772928,  0.96776869],
#        [ 1.65909422, -0.09855577],
#        [ 0.4997568 ,  0.74266118],
#        [-0.48452277,  0.78786736],
#        [ 0.20806969, -0.2745452 ],
#        [-0.67987721,  0.7260373 ],
#        [ 1.93522263,  0.02655141],
#        [-0.04281845,  0.92415092],
#        [-1.01960263,  0.27648403],
#        [ 0.19884758,  1.02437393],
#        [-0.42514525,  0.78024321],
#        [ 0.14849191, -0.24650788],
#        [ 0.49746097,  0.70934286],
#        [ 1.19673906, -0.47193292],
#        [ 1.81017595, -0.00568647],
#        [-1.18054076, -0.12955512],
#        [ 1.50364574, -0.35728724],
#        [ 0.67248924, -0.45196088],
#        [ 1.14050268, -0.46823261],
#        [ 1.00622705,  0.35225107],
#        [ 1.13448893, -0.50868142],
#        [ 0.51847208, -0.40046366],
#        [-0.5029259 ,  0.95751939],
#        [ 0.54372913,  0.82182444],
#        [ 0.15902979,  0.08539456],
#        [ 1.71557058, -0.23760522],
#        [ 2.07801833,  0.57551036],
#        [ 0.91431403, -0.61711572],
#        [-0.89797523,  0.41856471],
#        [ 1.75726338,  0.1076424 ],
#        [ 0.74327539, -0.52419973],
#        [-0.9255034 ,  0.05996143],
#        [-0.17609342,  0.33691588],
#        [-0.86464832, -0.03084997],
#        [-0.27121682,  0.92542491],
#        [ 0.32578659,  0.89167697],
#        [-0.1061946 ,  0.86749496],
#        [ 1.02514585,  0.05637464],
#        [ 0.28976594, -0.29183233],
#        [-0.94417718,  0.65550425],
#        [ 1.01286101,  0.40390668],
#        [ 0.11031427,  1.0339899 ],
#        [ 2.00497553,  0.39950046],
#        [ 0.15380187, -0.13034704],
#        [ 1.60648628, -0.26222526],
#        [ 0.05083151,  0.50128917],
#        [ 0.40953161,  0.84108745],
#        [ 1.27078704, -0.38602537],
#        [ 0.12964463,  0.0978833 ],
#        [ 0.75229311,  0.4324418 ],
#        [ 1.94752054, -0.14229304],
#        [ 0.76376354,  0.6228686 ],
#        [-0.75303157,  0.74102513],
#        [ 0.77068844,  0.63398045],
#        [ 1.18457985, -0.53571781],
#        [ 0.91611944,  0.60906225],
#        [ 0.2866303 ,  0.68643494],
#        [-0.09351407,  0.93010515],
#        [ 0.46463184, -0.22487486],
#        [ 0.14243569,  1.00766676],
#        [ 0.43128112, -0.29849218],
#        [-0.07147821,  0.40923327],
#        [ 1.9773488 ,  0.21449178],
#        [ 0.44074959,  1.11037483],
#        [-0.90206008,  0.2847102 ],
#        [ 1.95987566,  0.15439431],
#        [-0.01086156,  0.28335027],
#        [-0.20060746,  1.03163346],
#        [-1.00180969, -0.02808882],
#        [ 1.76435722, -0.03256025],
#        [-0.9371079 ,  0.22957606],
#        [ 1.18135863, -0.27085866],
#        [ 0.94162142,  0.59732403],
#        [ 0.17942178, -0.09716781],
#        [-0.06655555,  0.96743092],
#        [-1.00528492,  0.42602946],
#        [ 0.66979237, -0.51546821],
#        [ 0.33311474, -0.36260773],
#        [ 0.00584382,  0.18162101],
#        [-0.1809745 ,  1.08855995],
#        [ 1.35638265, -0.49956879],
#        [-0.72456777,  0.38056705],
#        [ 0.2146461 ,  0.11612907],
#        [-0.57119939,  0.37913861],
#        [ 1.35418673, -0.35593395],
#        [ 1.27743897, -0.41595652],
#        [-1.11256979,  0.4509148 ],
#        [ 0.78033788,  0.85259114],
#        [ 0.93806663,  0.31269273],
#        [ 0.13502786, -0.17841788],
#        [ 1.88357502, -0.07048225],
#        [ 1.42715549, -0.31691863],
#        [-0.34504592,  0.74630659],
#        [-0.09899701,  1.01354485],
#        [ 1.6752935 , -0.46123916],
#        [ 1.0481808 ,  0.6467562 ],
#        [-0.83204003,  0.4103748 ],
#        [-0.70845511,  0.59175395],
#        [ 1.70666492, -0.28126326],
#        [ 0.05254008,  0.26975405],
#        [ 0.8449636 ,  0.45121231],
#        [-0.04681271, -0.16505492],
#        [ 0.59890997,  1.05337551],
#        [ 1.94594755,  0.12929837],
#        [-0.97788446, -0.01833098],
#        [ 0.97355992, -0.49622335],
#        [-0.33459651,  0.90817771],
#        [ 0.68743262,  0.80222632],
#        [ 1.92920476,  0.29881814],
#        [ 1.17043626, -0.29689054],
#        [ 0.14467643,  0.94209079],
#        [ 0.18868257, -0.13078374],
#        [ 1.58057865, -0.2452404 ],
#        [ 0.80462707,  0.53112437],
#        [ 0.11364493,  0.22181946],
#        [ 0.58266606,  0.78129624],
#        [ 0.83171837,  0.76804192],
#        [ 0.71239048,  0.43312691],
#        [ 0.84948573,  0.28925205],
#        [ 1.52976066, -0.13725951],
#        [ 1.00978156,  0.23849607],
#        [ 1.38857232, -0.50250842],
#        [-0.57516967,  0.75972641],
#        [ 0.38398448,  1.10787617],
#        [ 1.10492412, -0.53468998],
#        [-0.00861355,  1.13188158],
#        [ 1.00536252, -0.55165289],
#        [-0.38218864,  1.02489323],
#        [ 0.92068959, -0.48024341],
#        [ 1.25670709, -0.40895852],
#        [ 1.42896893, -0.25275936],
#        [-0.4520445 ,  0.84222617],
#        [ 1.73797809, -0.08952452],
#        [ 0.83070285,  0.48623771],
#        [ 1.92678975,  0.48008602],
#        [ 0.57126534,  0.49062161],
#        [-0.97669303,  0.23428084],
#        [ 1.97921523,  0.11444735],
#        [ 0.94602484,  0.39405475],
#        [ 0.91840057, -0.45196158],
#        [-0.81080183,  0.55720156],
#        [ 0.04353164,  0.87651565],
#        [ 0.70306808,  0.7475159 ],
#        [-1.01217495,  0.22862669],
#        [ 0.88642803,  0.54397262],
#        [-1.19664022, -0.0320207 ],
#        [ 1.54363942, -0.3165411 ],
#        [ 1.76865273, -0.28112253],
#        [ 0.36672083,  0.89839134],
#        [ 0.76342742,  0.19493811],
#        [ 0.93723434,  0.33021298],
#        [ 2.00582682, -0.08646313],
#        [ 0.91783889,  0.17796276],
#        [ 2.04647893,  0.66407142],
#        [ 1.93592029,  0.45750566],
#        [ 0.99363215,  0.16110713],
#        [-0.15325684,  0.00766008],
#        [ 2.02719453,  0.19797654],
#        [-0.30915743,  0.84018752],
#        [ 0.95783343,  0.21213377],
#        [ 0.81227511, -0.31722786],
#        [ 0.63327087,  0.78595181],
#        [ 0.50304799, -0.29216209],
#        [-0.75999968,  0.49516107],
#        [-0.58353356,  0.7980456 ],
#        [ 1.89559271,  0.19669902],
#        [ 1.9468112 ,  0.1661806 ],
#        [-0.95241768,  0.03893231],
#        [ 0.071801  ,  0.23893351],
#        [ 0.24280118, -0.20537792],
#        [-0.60300629,  0.74357294],
#        [ 1.63371412, -0.24393027],
#        [ 0.27409039, -0.23649513],
#        [-0.87996409,  0.52400782],
#        [ 0.0118876 ,  0.85090063],
#        [ 1.52596592, -0.32775117],
#        [-0.74814411,  0.61493578],
#        [ 0.10155345, -0.15890007],
#        [ 0.16510567,  1.07961149],
#        [ 0.44969034, -0.16799425],
#        [ 0.2727224 , -0.23962163],
#        [-0.23562361,  0.98278215],
#        [ 0.83729863,  0.65932018],
#        [ 0.95725369,  0.68687512],
#        [-0.98055757,  0.18868663],
#        [ 0.32148786, -0.2967508 ],
#        [ 0.73338069,  0.34110864],
#        [-0.21389719,  1.00541566],
#        [ 0.69035811, -0.3269194 ],
#        [ 0.17858469,  0.07178725],
#        [ 1.17531612,  0.00871648],
#        [ 0.17743858,  0.12542869],
#        [-0.11117657,  1.17074947],
#        [ 0.4590535 , -0.42694765],
#        [ 0.22596188, -0.06897336],
#        [ 0.00896749,  0.10053503],
#        [ 0.32947633,  0.94075304],
#        [ 0.09701589,  0.38561844],
#        [ 0.45185658, -0.39540262],
#        [-0.91085067,  0.12354832],
#        [ 0.40310347, -0.42143851],
#        [-0.48116438,  0.66746882],
#        [-0.57442637,  0.77991846],
#        [ 0.67479356,  0.81698886],
#        [ 2.00046544,  0.26378047],
#        [ 1.88884165,  0.2403572 ],
#        [ 0.02206397,  0.86724591],
#        [ 0.03976863,  1.09181741],
#        [-0.15736971,  0.96832971],
#        [ 1.08963329, -0.4599995 ],
#        [ 2.12365925,  0.37148483],
#        [ 2.06300804,  0.16173619],
#        [ 1.20080157,  0.403211  ],
#        [ 0.80273475,  0.71688916],
#        [ 0.85535131,  0.02145355],
#        [ 0.47740348, -0.47441457],
#        [ 1.1225447 ,  0.08962613],
#        [ 1.90350799, -0.04590249],
#        [ 1.43735971, -0.45052549],
#        [ 0.22376909,  0.21767639],
#        [-0.45660239,  0.7342351 ],
#        [ 0.9731788 , -0.14782814],
#        [-0.11219248,  0.77266744],
#        [-0.68612759,  0.5085518 ],
#        [ 0.38332778,  0.98729117],
#        [ 1.8571354 ,  0.14292214],
#        [-0.5317183 ,  1.05354007],
#        [ 1.89686486,  0.28116983],
#        [ 0.96004501,  0.08943111],
#        [-0.61453897,  0.67321392],
#        [ 1.04555764, -0.57680556],
#        [ 0.92942621,  0.08261985],
#        [ 1.32712939, -0.4406233 ],
#        [ 0.42338986,  0.93220157],
#        [-0.45593394,  1.08958622],
#        [ 1.48057538, -0.35561679],
#        [ 0.91757925, -0.00237115],
#        [-0.64690105,  0.84810218],
#        [ 1.70960996,  0.13276303],
#        [ 0.69777239,  0.70400662],
#        [ 1.61413197, -0.1665777 ],
#        [ 0.9939167 ,  0.22594273],
#        [ 0.26968312,  0.86593825],
#        [ 0.37368395, -0.28057523],
#        [ 0.48973274,  0.79445289],
#        [ 1.03593864,  0.05909857],
#        [ 2.04490749,  0.12427958],
#        [ 0.52805281, -0.41658675],
#        [ 0.20379964, -0.29009477],
#        [ 0.37309629, -0.32105802],
#        [ 1.65970494,  0.06659871],
#        [ 2.07658541,  0.29871419],
#        [ 0.13703243,  0.01060199],
#        [ 0.16785395,  0.09723284],
#        [ 0.1790212 , -0.29428049],
#        [-1.00726677,  0.10603501],
#        [ 0.12601723,  0.10795056],
#        [ 0.72413073, -0.48786216],
#        [ 1.99296716, -0.09213339],
#        [ 0.89704369, -0.29576732],
#        [ 1.24388418, -0.32902737],
#        [-0.8590145 ,  0.10636474],
#        [ 1.39489278, -0.43087525],
#        [-0.22403912,  0.97149619],
#        [ 0.16597081,  0.0801811 ],
#        [-0.88578309,  0.47713343],
#        [-0.03997932,  1.11963945],
#        [ 2.03872866,  0.26950037],
#        [ 0.91585656, -0.43151736],
#        [ 1.94429314,  0.17133918],
#        [ 1.73334617, -0.43277684],
#        [-0.93512684,  0.52930329],
#        [ 1.49546415, -0.38347685],
#        [ 1.94677779,  0.34765858],
#        [ 0.39213887, -0.35185118],
#        [-0.84160445,  0.27715972],
#        [-0.61207537,  0.83640755],
#        [ 0.75108767,  0.57116176],
#        [ 0.49205508, -0.19588807],
#        [ 0.56749042, -0.3520772 ],
#        [ 0.01961543,  0.23827742],
#        [ 0.95255008, -0.47358823],
#        [ 2.0574141 ,  0.08868969],
#        [ 1.9322288 ,  0.0476669 ],
#        [-0.69219495,  0.70275346],
#        [ 0.75617485,  0.65260323],
#        [-0.94801987,  0.11495352],
#        [ 0.41362198,  0.88487172],
#        [-0.99534463,  0.20341551],
#        [ 0.9438895 ,  0.3314296 ],
#        [ 0.40829994,  0.9135055 ],
#        [-0.56340023,  0.67659832],
#        [ 0.70996326,  0.84231524],
#        [ 1.75774983, -0.1147813 ],
#        [ 0.81390729,  0.60576442],
#        [-0.5441999 ,  0.62833148],
#        [ 0.63075073, -0.55136485],
#        [-0.75501773,  0.68749303],
#        [ 0.1109302 ,  0.25230272],
#        [ 0.01874604,  0.98261513],
#        [-0.93238217,  0.40739473],
#        [ 0.2354102 , -0.05243406],
#        [ 0.33725105, -0.28371278],
#        [ 0.66626857,  0.92473598],
#        [ 0.61353442,  0.89400068],
#        [-0.28908121,  1.06779568],
#        [ 1.92293008,  0.26347522],
#        [ 0.57456754, -0.5071948 ],
#        [ 0.59061185, -0.53899361],
#        [ 0.95171523, -0.52565199],
#        [ 0.08977408,  0.39102336],
#        [ 0.29704227, -0.28368589],
#        [-0.05912213,  0.1218562 ],
#        [ 1.78647092, -0.19819036],
#        [ 1.94090157,  0.1891832 ],
#        [-0.89073033,  0.18488717],
#        [ 0.70559036,  0.60273323],
#        [ 1.41792159, -0.4160469 ],
#        [ 0.64027703, -0.34587905],
#        [ 1.21235422, -0.45238903],
#        [ 1.2777004 , -0.46919846],
#        [ 0.28604098,  0.74472098],
#        [ 0.40897802,  1.11178731],
#        [ 1.969834  ,  0.14549566],
#        [ 1.0681212 , -0.51650621],
#        [ 0.73466947, -0.42086062],
#        [-0.11418947,  0.98843896],
#        [ 0.27466503,  0.87418457],
#        [-0.54677169,  0.99007183],
#        [ 0.97328276, -0.38701907],
#        [-0.40487464,  0.94056503],
#        [ 0.07470847,  0.37779355],
#        [ 0.28546624, -0.29048119],
#        [ 0.66845581,  0.61152589],
#        [ 0.82813049,  0.29988472],
#        [ 1.74735916, -0.0257628 ],
#        [ 1.6266487 , -0.30552837],
#        [ 1.95165924,  0.20932191],
#        [-0.6797084 ,  0.74259119],
#        [-0.97206952,  0.65002502],
#        [-0.02175356,  0.42525742],
#        [ 0.55419551, -0.52313301],
#        [ 0.07217874, -0.09260691],
#        [-0.24328031,  0.43882732],
#        [-0.90208057,  0.67927484],
#        [ 1.65940475, -0.13481292],
#        [ 2.01041248, -0.02607526],
#        [-0.83473555,  0.48665131],
#        [ 0.5556458 , -0.36762513],
#        [ 2.01666997,  0.10964787],
#        [ 1.28122777, -0.53359508],
#        [ 0.12007527,  0.96928799],
#        [ 1.11183763, -0.40694057],
#        [ 0.93476687,  0.40272204],
#        [ 0.19077025, -0.27874317],
#        [ 0.94736633, -0.50652523],
#        [-0.32549915,  0.93032652],
#        [ 1.78361035,  0.08958107],
#        [ 0.20160022,  1.13819189],
#        [-1.00319855,  0.1112358 ],
#        [ 1.18755605,  0.14528703],
#        [ 0.07448067, -0.06530408],
#        [ 1.86992249, -0.14780927],
#        [ 0.71711776,  0.76487816],
#        [-1.20824768,  0.19170384],
#        [-0.9298414 ,  0.183961  ],
#        [ 0.12662677,  1.21598533],
#        [ 1.88105839,  0.38233537],
#        [ 0.55139982, -0.50721543],
#        [-0.06434713,  0.29270165],
#        [ 0.15953361,  0.95255704],
#        [ 1.44080129, -0.39199011],
#        [ 0.95087452,  0.75056741],
#        [ 0.18304957,  0.02765932]])

# %%
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))

# %%
# group dataset by label
grouped = df.groupby('label')

# plot classification dataset
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key], figsize=(10,8))
plt.show()

# %%
df.to_csv("dataset/class_moons.csv")

# %% [markdown]
# ## 2.3 make_circles

# %%
from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples=500, noise=0.05)

# %%
# scatter plot, dots colored by class value
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
df.head()
# Out:
#           x         y  label
# 0 -0.039534 -0.805153      1
# 1  0.610079 -0.605193      1
# 2  0.719798  0.203198      1
# 3 -0.199165  0.809115      1
# 4  0.950020 -0.204734      0

# %%
# group dataset by label
grouped = df.groupby('label')

# plot classification dataset
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key], figsize=(10,8))
plt.show()

# %%
df.to_csv("dataset/class_circles.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Building the dataset
#
# - generate regression dataset
# - generate classification dataset

# %% [markdown]
# ## 1. Regression Dataset

# %%
from sklearn.datasets import make_regression

# %%
# generate regression dataset
X, y = make_regression(n_samples=1000, n_features=1, noise=100, shuffle=True, random_state=27)

# %%
df = pd.DataFrame(X, index=range(len(X)), columns=["X"])
df["Y"] = y

# %%
df.head()
# Out:
#           X           Y
# 0 -0.168005 -107.480692
# 1  1.393876  201.944833
# 2 -0.250787   84.740862
# 3  0.013533   60.527183
# 4 -0.776702  -26.201326

# %%
df.to_csv("dataset/reg_uni.csv")

# %%
# plot regression dataset
plt.figure(figsize=(10,10))
plt.scatter(X,y)
plt.show()

# %%
# generate regression dataset
X, y = make_regression(n_samples=50, n_features=3, noise=0.1, shuffle=True, random_state=27)

# %%
X.shape
# Out:
# (50, 3)

# %%
df = pd.DataFrame(dict(X1=X[:,0], X2=X[:, 1], X3=X[:,2], Y=y))
df.head()
# Out:
#          X1        X2        X3           Y
# 0 -2.166068 -1.247767  0.285685 -184.980982
# 1  0.154733  0.562757  1.033058  136.596165
# 2 -0.144426  0.591353 -0.037168   10.231184
# 3  1.501099  0.195870  1.901946  307.014161
# 4  1.056678  0.056822 -0.020623   78.958628

# %%
# plot regression dataset
plt.figure(figsize=(10,10))
plt.scatter(df["X1"], df["Y"], color="r")
plt.scatter(df["X2"], df["Y"], color="g")
plt.scatter(df["X3"], df["Y"], color="b")
plt.show()

# %%
df.to_csv("dataset/reg_mult.csv")

# %% [markdown]
# ## 2. Classification dataset

# %% [markdown]
# ## 2.1 make_blobs

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=100, centers=3, n_features=2)

# %%
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
df.head()
# Out:
#           x         y  label
# 0  8.020241 -2.943367      1
# 1 -0.021773 -1.655047      0
# 2  1.040343 -2.189574      0
# 3  6.436294 -4.730907      1
# 4 -2.292067  9.863081      2

# %%
# group dataset by label
grouped = df.groupby('label')

# plot classification dataset
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = plt.subplots()
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key], figsize=(10,8))
plt.show()

# %%
df.to_csv("dataset/class_blobs.csv")

# %% [markdown]
# ## 2.2 make_moons

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=500, noise=0.1)

# %%
X
# Out:
# array([[ 1.8373632 , -0.33276725],
#        [ 1.9939197 ,  0.05768018],
#        [-0.07814388, -0.15660004],
#        [ 0.50728632,  0.80593473],
#        [ 0.35876817,  1.06587832],
#        [ 0.75539733,  0.77773315],
#        [ 0.88861345,  0.43169144],
#        [ 0.52550193, -0.48317296],
#        [ 0.97484945,  0.25750482],
#        [-1.08533847, -0.04447074],
#        [-0.20933971,  0.99536258],
#        [ 0.80922925, -0.33301723],
#        [ 0.05368629,  0.47427561],
#        [-0.39136619,  1.08429622],
#        [-0.16556812,  0.92162312],
#        [ 0.97618505,  0.16697279],
#        [ 0.76553023,  0.55962585],
#        [ 1.47536986, -0.35693508],
#        [-0.56669561,  1.03412202],
#        [ 0.43289549,  0.99316892],
#        [-0.763982  ,  0.6999212 ],
#        [ 0.38527392, -0.24483768],
#        [ 1.2204581 , -0.29893292],
#        [ 1.3059574 , -0.30672095],
#        [-0.66223243,  0.8989976 ],
#        [ 0.34591744,  0.71140474],
#        [ 0.09884823,  0.08015904],
#        [ 0.04343964,  0.79260497],
#        [-0.42000809,  0.80105033],
#        [-0.84097305,  0.14861792],
#        [ 1.69038325, -0.11808776],
#        [ 0.21038734,  1.04123405],
#        [-0.09856228,  0.3479558 ],
#        [ 1.48432611, -0.45690998],
#        [ 1.15803365, -0.42290193],
#        [-0.61831763,  0.59840118],
#        [ 0.21472147, -0.2526234 ],
#        [-0.39188853,  0.98042355],
#        [-0.55436559,  0.681943  ],
#        [-0.16462882,  0.97368334],
#        [ 0.7608443 , -0.53891079],
#        [ 0.49324675, -0.35608059],
#        [ 0.85108687,  0.53548252],
#        [ 1.09546425,  0.03248956],
#        [ 0.30660648,  0.81059596],
#        [ 0.86421176,  0.53187485],
#        [ 0.13262482,  0.04153577],
#        [ 0.36625337,  0.99772092],
#        [ 1.33280799, -0.31253546],
#        [ 0.18983558,  0.02087248],
#        [-0.96251133,  0.30957259],
#        [ 1.07546337, -0.42032044],
#        [ 0.4871559 ,  0.73778097],
#        [ 1.17788798, -0.55785321],
#        [ 0.04937091,  0.43520218],
#        [-0.51455582,  0.63312461],
#        [ 1.96429857,  0.49717205],
#        [-0.98787246,  0.5300991 ],
#        [ 0.46128456, -0.1835081 ],
#        [-0.31194123,  0.84699723],
#        [ 0.85317545, -0.64550284],
#        [ 0.66186264,  0.79375281],
#        [ 0.88474721,  0.69667618],
#        [-0.25290787,  0.97039934],
#        [ 0.05974766,  0.35158034],
#        [-0.83821399,  0.14279261],
#        [ 1.51078153, -0.38250956],
#        [ 1.49872964, -0.30476633],
#        [ 1.7359734 , -0.13070013],
#        [-0.96642431,  0.14215754],
#        [ 0.22241145,  0.84423264],
#        [-0.4211818 ,  0.83865134],
#        [ 0.48391332, -0.37308839],
#        [-0.69798173,  0.36338178],
#        [ 0.20702796,  0.01921334],
#        [ 1.0442189 ,  0.18002525],
#        [ 1.05974279, -0.2602264 ],
#        [ 0.1761193 ,  0.92680967],
#        [ 0.87218373,  0.27177826],
#        [ 0.1925905 ,  0.47423387],
#        [-0.091436  ,  0.03106006],
#        [ 0.28478472,  0.91144351],
#        [ 1.35616233, -0.41828672],
#        [-0.90373581,  0.00347186],
#        [ 0.72820314,  0.62360285],
#        [-0.84252323,  0.32097753],
#        [ 0.85843638,  0.54912156],
#        [ 0.21319292,  1.06949936],
#        [ 0.02890644,  0.62302961],
#        [-0.88670019,  0.3994164 ],
#        [ 1.00555154,  0.19357995],
#        [ 0.10635625,  0.02763619],
#        [-1.03573788,  0.02205213],
#        [-0.37790191,  0.95376138],
#        [-0.23203978,  0.93409066],
#        [ 0.183385  ,  0.29263603],
#        [-0.82938973,  0.51999201],
#        [-0.8912521 ,  0.0130572 ],
#        [-0.82526228,  0.49372034],
#        [ 0.4252396 , -0.44380232],
#        [ 0.58615263,  0.60386698],
#        [-0.72654738,  0.51605154],
#        [ 0.79785939, -0.42637263],
#        [ 0.47335138, -0.37862598],
#        [-0.51206025,  0.69629147],
#        [-0.14963674,  1.10045527],
#        [ 1.05627547, -0.12053659],
#        [-0.07211686,  0.28400466],
#        [-0.58998315,  0.62020922],
#        [-0.0707898 ,  0.32833824],
#        [ 0.11326507,  1.11765685],
#        [-0.05566613,  0.89818445],
#        [ 1.40116221, -0.39415047],
#        [ 1.13644123, -0.57766572],
#        [ 0.41819538, -0.22814747],
#        [-0.51357261,  0.84493044],
#        [ 2.05904685,  0.36034458],
#        [ 0.37423468, -0.27471704],
#        [ 0.36991735, -0.39800976],
#        [-0.2257498 ,  0.99076646],
#        [ 1.90522055,  0.21279928],
#        [ 0.34954039, -0.39009494],
#        [ 0.40269638,  0.77890331],
#        [-0.03363274,  0.92746501],
#        [-0.37092893,  0.73322156],
#        [ 1.63752913, -0.49084859],
#        [-0.56779447,  0.51298204],
#        [ 0.46085207,  0.81252934],
#        [ 0.65060489,  0.77894343],
#        [ 1.95525863,  0.12602765],
#        [ 0.67210289, -0.37610626],
#        [ 1.63997715, -0.47711665],
#        [ 1.06496208, -0.57548588],
#        [ 0.81069752,  0.47731861],
#        [ 0.03108894,  0.19897411],
#        [ 0.40272172, -0.43472729],
#        [ 1.05638986, -0.40191062],
#        [-0.21194518,  0.98318694],
#        [ 0.5507261 ,  0.746238  ],
#        [ 0.420482  ,  0.80403537],
#        [ 0.3440855 ,  1.03893539],
#        [ 1.36594621, -0.45014997],
#        [-0.30330562,  0.99763982],
#        [ 0.11223222,  0.04723688],
#        [ 2.01567482,  0.22877705],
#        [ 0.35887892, -0.08062278],
#        [ 0.47486119, -0.38593937],
#        [ 0.80705544,  0.63753528],
#        [ 0.26408543, -0.12371474],
#        [ 1.96548193,  0.60962356],
#        [ 1.7249561 , -0.18434964],
#        [ 0.44644314, -0.25781943],
#        [ 1.88820452,  0.43287217],
#        [ 0.20745067,  0.07253086],
#        [ 1.70611979, -0.40874042],
#        [ 1.90071752,  0.08108518],
#        [ 0.82913067, -0.4951234 ],
#        [-0.91474293,  0.02553162],
#        [ 1.70951085, -0.26019417],
#        [ 0.90218188,  0.36368596],
#        [ 0.36811254,  0.96035755],
#        [ 0.63629163, -0.5844078 ],
#        [ 1.76346424,  0.00874164],
#        [ 1.46653484, -0.28801411],
#        [ 0.23540755, -0.0954692 ],
#        [ 0.01478202,  0.46801076],
#        [ 0.1091364 ,  1.03333151],
#        [ 1.41990051, -0.35272827],
#        [ 0.60184577, -0.42602573],
#        [ 1.12766506, -0.51348428],
#        [ 0.02534741,  1.11960633],
#        [ 0.28729543, -0.23263091],
#        [ 0.19604424,  0.04566216],
#        [ 0.25406759, -0.0114591 ],
#        [ 0.77401199,  0.38069352],
#        [ 0.58461241,  0.77620346],
#        [ 0.46569087,  0.96090875],
#        [-1.17530773,  0.19926132],
#        [ 0.9296529 ,  0.21445902],
#        [-0.16685669,  0.8951068 ],
#        [ 1.56600502, -0.54896871],
#        [ 1.10817513,  0.34409103],
#        [-0.67881318,  0.77324304],
#        [ 1.96248603,  0.34188329],
#        [ 0.74642678, -0.40342785],
#        [ 1.10987991, -0.52012034],
#        [-0.17669344,  0.90533918],
#        [ 0.88586004,  0.37196605],
#        [ 0.81206418, -0.47125938],
#        [-0.4730016 ,  0.8686225 ],
#        [ 1.06869906, -0.00866291],
#        [ 1.69018906, -0.2556636 ],
#        [ 0.77919869, -0.53052   ],
#        [-0.93026302,  0.579796  ],
#        [ 1.75650073, -0.09583722],
#        [ 0.92787813, -0.43363493],
#        [ 1.81936131, -0.48813517],
#        [-0.57063229,  0.72217256],
#        [ 0.93587986, -0.39112058],
#        [-0.9829536 ,  0.12281122],
#        [ 0.22361378, -0.01169995],
#        [-0.87578309,  0.52775185],
#        [ 0.29536789, -0.05173112],
#        [ 1.21129111, -0.55962232],
#        [ 0.11561884, -0.14351909],
#        [ 1.00822566, -0.01749417],
#        [-0.9739905 ,  0.19632852],
#        [ 0.51212527,  0.771322  ],
#        [ 2.02385027,  0.49991323],
#        [ 0.01349024,  0.15918813],
#        [ 1.74132738, -0.06411612],
#        [ 0.06216964,  0.45901951],
#        [ 1.11235402,  0.37520869],
#        [ 0.98062002,  0.20538011],
#        [-0.3455414 ,  0.91549493],
#        [-0.79318771,  0.78122221],
#        [ 1.97013044,  0.20588519],
#        [ 0.23081261,  0.41011732],
#        [ 2.00401935, -0.0045036 ],
#        [-0.79741905,  0.6202726 ],
#        [ 1.92689371, -0.04345364],
#        [-0.89440774,  0.57467303],
#        [ 0.0767175 ,  0.78635247],
#        [ 1.88651604,  0.13048977],
#        [ 1.04757187,  0.10792072],
#        [ 0.46766357, -0.17648918],
#        [-0.05384663,  0.57585629],
#        [-0.60479227,  0.61303248],
#        [ 2.13631015,  0.62591234],
#        [ 0.98451409, -0.49505079],
#        [-0.67137333,  0.50472253],
#        [ 1.58708262, -0.49259413],
#        [ 0.72935634,  0.45694795],
#        [ 1.71786796, -0.07104199],
#        [ 0.63098799,  0.6942374 ],
#        [ 1.00853863, -0.53550158],
#        [-0.67870465,  0.73111609],
#        [-0.70741161,  0.65738831],
#        [-0.36112844,  0.99002156],
#        [ 0.81123336,  0.59321793],
#        [ 1.28697281, -0.42601679],
#        [ 0.27052028, -0.2003056 ],
#        [ 0.63059307,  0.71062949],
#        [ 2.04050824,  0.23600955],
#        [ 2.02344753,  0.36980038],
#        [ 1.80610245, -0.12489074],
#        [ 1.7853912 , -0.01827236],
#        [-0.17352964,  1.10414118],
#        [-0.24437065,  1.03355442],
#        [ 0.61505083, -0.45808818],
#        [ 0.05402746,  0.52700357],
#        [-0.92193436,  0.67153797],
#        [ 0.74434772, -0.42600256],
#        [-1.15120587,  0.33068325],
#        [-0.05232334,  0.22260015],
#        [ 1.90023988,  0.22943835],
#        [ 1.66445925, -0.21725924],
#        [ 0.6731164 ,  0.65774516],
#        [ 0.10488545, -0.21608774],
#        [-0.30153318,  0.90263334],
#        [ 1.86807855,  0.27120557],
#        [ 1.36533252, -0.37504511],
#        [-0.89839683,  0.65284687],
#        [ 1.61078817, -0.25527469],
#        [ 0.5074681 , -0.40189808],
#        [ 0.21854753,  0.93055485],
#        [-0.80588531,  0.49834971],
#        [ 2.05381368,  0.05450629],
#        [ 0.20160845,  0.92663285],
#        [ 1.89476379,  0.03064736],
#        [ 0.91158235,  0.46921639],
#        [-0.94031342,  0.61051568],
#        [ 1.47554651, -0.54252884],
#        [ 1.55841416, -0.48436834],
#        [ 1.83975231,  0.3007934 ],
#        [ 0.08494034,  0.97256452],
#        [ 0.68478656, -0.42453268],
#        [-0.60506972,  0.73884598],
#        [ 0.89175786, -0.44598971],
#        [ 1.52728059, -0.31877257],
#        [-0.91759327,  0.37784743],
#        [ 1.45970212, -0.49440781],
#        [ 0.2248299 ,  1.03325779],
#        [ 0.99364702, -0.51082086],
#        [ 0.74352678,  0.60244936],
#        [-0.99112262, -0.08373342],
#        [ 1.22922976, -0.4388293 ],
#        [ 1.714514  , -0.26602111],
#        [ 1.85616916,  0.27188562],
#        [-1.10871839,  0.39410391],
#        [ 1.95840146,  0.29327921],
#        [ 0.92355295, -0.61152164],
#        [ 1.03755494,  0.31206487],
#        [ 1.96453231,  0.45804822],
#        [ 0.10992186,  0.17165832],
#        [ 1.05512549,  0.57054207],
#        [-0.40894239,  0.81484616],
#        [-0.77933473,  0.59080525],
#        [ 0.32478903, -0.34219205],
#        [ 1.80853695, -0.04017295],
#        [ 0.45094033,  0.88806704],
#        [ 0.08463778,  0.30294196],
#        [ 1.43981249, -0.41333888],
#        [-0.43515924,  0.78996615],
#        [ 0.1975724 ,  0.11071903],
#        [-0.8225361 ,  0.45875507],
#        [ 0.473436  ,  0.80419987],
#        [ 0.72647086,  0.75025818],
#        [ 1.35119238, -0.47131099],
#        [ 0.10549791,  1.10324655],
#        [-0.6157313 ,  0.6870523 ],
#        [ 0.55716348, -0.43209173],
#        [ 0.58539367, -0.26044601],
#        [ 0.21750863, -0.39263818],
#        [-0.99832279,  0.15629325],
#        [-0.15767814,  1.05930236],
#        [ 1.15095191,  0.00459884],
#        [ 0.80173514,  0.58080544],
#        [-0.85377382,  0.1155417 ],
#        [ 0.6124969 ,  0.72638673],
#        [ 0.7153176 , -0.3539721 ],
#        [ 0.63667568,  0.78650057],
#        [-0.94988532,  0.14216195],
#        [ 1.17623296,  0.26701594],
#        [ 0.52896213, -0.40519542],
#        [ 0.50286716,  0.91357922],
#        [ 0.26911034,  1.06867317],
#        [ 1.90394058,  0.44194657],
#        [ 1.02011623, -0.36187932],
#        [ 1.59210735, -0.29449457],
#        [-0.93506769,  0.14038747],
#        [ 2.05339348,  0.23782088],
#        [ 0.44167773,  0.84089562],
#        [-0.30095851,  0.81931323],
#        [-0.12257045,  0.90587917],
#        [ 1.74812107, -0.10163271],
#        [ 0.08510215, -0.09065482],
#        [ 0.88514958,  0.34130314],
#        [ 1.78639289,  0.09700072],
#        [ 0.93826181,  0.22834201],
#        [ 1.01028731, -0.44758989],
#        [ 1.92647446,  0.12280232],
#        [-1.04337611,  0.53153579],
#        [ 0.05463977,  0.31885288],
#        [ 0.08301878, -0.17277752],
#        [-0.85913093,  0.04394115],
#        [ 1.12426822, -0.41038856],
#        [ 1.02816044, -0.10159516],
#        [-0.78625363,  0.82351044],
#        [ 0.22796582,  0.8822398 ],
#        [ 2.01835722,  0.45587443],
#        [ 1.08710801, -0.50012904],
#        [-1.02893285,  0.30195453],
#        [-0.93701309,  0.01895258],
#        [ 1.39943487, -0.54187757],
#        [ 1.85829793,  0.10705026],
#        [ 0.23853276, -0.01955025],
#        [ 0.44404841,  0.92711045],
#        [-0.46643444,  0.83839863],
#        [ 0.28867628,  1.11762441],
#        [-0.05659952,  0.29019716],
#        [ 0.9697814 ,  0.64973828],
#        [ 0.99438821,  0.72436822],
#        [-0.01500076,  0.1906006 ],
#        [ 0.08664986,  0.98072283],
#        [ 1.99043401,  0.27376204],
#        [ 1.90274576, -0.06745617],
#        [ 0.91938069, -0.74272668],
#        [-0.92514172,  0.16358633],
#        [ 0.45644285,  1.09721315],
#        [-0.10557279,  1.01976445],
#        [ 0.12149463,  0.31655831],
#        [ 0.4907291 , -0.32923842],
#        [ 0.86724205,  0.42904834],
#        [-0.72899957,  1.01140477],
#        [ 1.90014273,  0.15913637],
#        [ 1.85121578,  0.02492547],
#        [ 1.93493292,  0.46758822],
#        [ 0.59414075, -0.39656627],
#        [-0.01987622,  0.91959217],
#        [ 0.0843714 ,  0.21911416],
#        [ 0.58619355,  0.78814616],
#        [ 0.91868004, -0.01203404],
#        [-0.49869446,  0.74066789],
#        [ 1.77694431,  0.20427475],
#        [-0.89052895,  0.35666748],
#        [ 0.27071964, -0.24275751],
#        [ 0.52604334, -0.56051543],
#        [ 0.54533052,  0.66073308],
#        [-0.88092209,  0.37852878],
#        [ 1.86178961, -0.08265425],
#        [ 0.938238  ,  0.43976463],
#        [ 1.75467105,  0.40065256],
#        [ 0.62531246, -0.48667909],
#        [-0.28920865,  1.00387414],
#        [ 0.61032602,  0.58661024],
#        [-0.12960394,  1.01555466],
#        [ 0.72838331,  0.78322154],
#        [-0.68828762,  0.89861416],
#        [ 0.54785822, -0.34471292],
#        [ 0.48596905, -0.48939377],
#        [ 0.66579273, -0.32349926],
#        [-1.0408296 ,  0.1898304 ],
#        [ 1.8414663 ,  0.12043405],
#        [ 0.80486666,  0.18670592],
#        [-0.63951407,  0.8395011 ],
#        [-0.94278559,  0.02001107],
#        [-0.38324558,  0.71398791],
#        [-1.01755664,  0.14926301],
#        [ 0.03921375,  0.91114081],
#        [-0.89713091,  0.44669227],
#        [-0.85871645,  0.38080436],
#        [ 0.17498346,  0.94554619],
#        [ 0.0751903 ,  0.40317824],
#        [ 1.5149888 , -0.40421562],
#        [ 1.96136844, -0.22797161],
#        [-0.48852425,  0.66568857],
#        [ 0.70716013, -0.52271076],
#        [ 0.53269204, -0.57089345],
#        [ 0.25987661,  0.89151637],
#        [ 0.93849089,  0.10314278],
#        [ 1.43194318, -0.43166957],
#        [ 2.08132295,  0.52053131],
#        [-0.94520963,  0.30272639],
#        [ 0.21333578,  0.01221832],
#        [ 1.92750972, -0.0967647 ],
#        [ 1.19191737, -0.45284655],
#        [ 0.6919677 ,  0.75794549],
#        [ 0.95641864, -0.37224124],
#        [-0.94039485,  0.7598786 ],
#        [-1.11183836,  0.37173551],
#        [ 0.23090099, -0.19671474],
#        [-1.06146264,  0.37418289],
#        [-1.08429402,  0.56655727],
#        [ 2.01724015,  0.14045265],
#        [ 1.28868076, -0.31878348],
#        [ 0.68079092,  0.81292388],
#        [ 0.17417154,  1.13218412],
#        [-0.21863598,  1.07852893],
#        [ 0.75756116, -0.50444147],
#        [ 1.70299607, -0.18822   ],
#        [-0.89122736,  0.38978081],
#        [ 1.95610861,  0.05695694],
#        [ 1.10422643,  0.26933285],
#        [ 0.38697704, -0.51743394],
#        [ 0.74197745,  0.65174249],
#        [ 0.35444988,  1.11490006],
#        [ 1.04267475, -0.41246367],
#        [ 0.21455747, -0.21045362],
#        [ 1.65644348, -0.21470625],
#        [ 0.78522531,  0.54757466],
#        [-0.00853503,  0.17993782],
#        [ 0.93421404,  0.30951235],
#        [ 1.46087353, -0.50512067],
#        [ 0.76900646,  0.71119497],
#        [ 1.6368617 , -0.32742204],
#        [ 0.21513184, -0.29685391],
#        [-0.14368192,  0.30079949],
#        [ 1.82218428, -0.32812036],
#        [ 0.96287187,  0.19541208],
#        [ 0.84858431, -0.49491922],
#        [-0.18757067,  1.03741728],
#        [-0.25136937,  0.88722459],
#        [ 1.06214853,  0.48421056],
#        [ 0.93363736,  0.21049014],
#        [ 1.08748868, -0.59706905],
#        [ 0.07661995,  0.37500103],
#        [ 0.22549607, -0.3991496 ],
#        [ 2.13685875,  0.45878735],
#        [-0.01887899, -0.06192496],
#        [ 1.86488667, -0.1920691 ],
#        [ 0.84883715, -0.45654165],
#        [-0.01796196,  1.0274743 ],
#        [ 0.23937434,  0.05027726],
#        [ 0.20769351,  0.14553783],
#        [ 0.74824854,  0.49114088],
#        [ 0.16114714,  0.984304  ],
#        [ 1.9899288 ,  0.44473131],
#        [ 0.12127952, -0.06337815],
#        [ 0.94175598,  0.40806794],
#        [-0.19061497,  0.99351681],
#        [ 0.09426252,  0.10739427],
#        [ 1.07185916,  0.01380128],
#        [ 0.67090995,  0.75047245],
#        [ 1.05764747,  0.10981235],
#        [-0.51516631,  0.9643146 ],
#        [-0.14768104, -0.11324747],
#        [-0.45079786,  0.93751974],
#        [ 1.76783622, -0.11070253],
#        [-0.77364591,  0.51785141],
#        [ 0.31553088, -0.26169675],
#        [ 0.98724695,  0.44020482],
#        [-0.91743266,  0.22199884],
#        [ 0.95285246,  0.23554818],
#        [ 0.12199666, -0.0841804 ],
#        [ 0.97881995, -0.4453034 ],
#        [ 1.79951994, -0.07113137],
#        [ 1.10800029, -0.56213445],
#        [ 1.17591678, -0.52045504],
#        [ 0.87309372,  0.17636136]])

# %%
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))

# %%
# group dataset by label
grouped = df.groupby('label')

# plot classification dataset
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key], figsize=(10,8))
plt.show()

# %%
df.to_csv("dataset/class_moons.csv")

# %% [markdown]
# ## 2.3 make_circles

# %%
from sklearn.datasets import make_circles

# %%
X, y = make_circles(n_samples=500, noise=0.05)

# %%
# scatter plot, dots colored by class value
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
df.head()

# %%
# group dataset by label
grouped = df.groupby('label')

# plot classification dataset
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key], figsize=(10,8))
plt.show()

# %%
df.to_csv("dataset/WasawatB/class_circles.csv")
